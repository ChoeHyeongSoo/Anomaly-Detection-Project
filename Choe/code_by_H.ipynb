# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ## 1. 데이터 불러오기

# %% [markdown]
# ### 필수 라이브러리

# %%
import os
from pprint import pprint

import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
#from tqdm import tqdm

# %% [markdown]
# ### 데이터 읽어오기

# %%
ROOT_DIR = "data"
RANDOM_STATE = 110

# Load data
train_data = pd.read_csv(os.path.join(ROOT_DIR, "train.csv"))
train_data
# Out:
#       Wip Line_Dam Process Desc._Dam     Equipment_Dam Model.Suffix_Dam  \
# 0          IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334505
# 1          IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334505
# 2          IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 3          IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 4          IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
# ...            ...               ...               ...              ...
# 40501      IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
# 40502      IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 40503      IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
# 40504      IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 40505      IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
#
#       Workorder_Dam  Insp. Seq No._Dam Insp Judge Code_Dam  \
# 0        4F1XA938-1                  1                  OK
# 1        3KPM0016-2                  1                  OK
# 2        4E1X9167-1                  1                  OK
# 3        3K1X0057-1                  1                  OK
# 4        3HPM0007-1                  1                  OK
# ...             ...                ...                 ...
# 40501    3J1XF434-2                  1                  OK
# 40502    4E1XC796-1                  1                  OK
# 40503    4C1XD438-1                  1                  OK
# 40504    3I1XA258-1                  1                  OK
# 40505    3G1XA501-1                  1                  OK
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION X Unit Time_Dam  CURE END POSITION X Judge Value_Dam  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 40501                                NaN                                  NaN
# 40502                                NaN                                  NaN
# 40503                                NaN                                  NaN
# 40504                                NaN                                  NaN
# 40505                                NaN                                  NaN
#
#        ...  Production Qty Collect Result_Fill2  \
# 0      ...                                    7
# 1      ...                                  185
# 2      ...                                   10
# 3      ...                                  268
# 4      ...                                  121
# ...    ...                                  ...
# 40501  ...                                  318
# 40502  ...                                   14
# 40503  ...                                    1
# 40504  ...                                  117
# 40505  ...                                  320
#
#        Production Qty Unit Time_Fill2  Production Qty Judge Value_Fill2  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 40501                             NaN                               NaN
# 40502                             NaN                               NaN
# 40503                             NaN                               NaN
# 40504                             NaN                               NaN
# 40505                             NaN                               NaN
#
#        Receip No Collect Result_Fill2  Receip No Unit Time_Fill2  \
# 0                                 127                        NaN
# 1                                   1                        NaN
# 2                                  73                        NaN
# 3                                   1                        NaN
# 4                                   1                        NaN
# ...                               ...                        ...
# 40501                               1                        NaN
# 40502                             197                        NaN
# 40503                              27                        NaN
# 40504                               1                        NaN
# 40505                               1                        NaN
#
#        Receip No Judge Value_Fill2  WorkMode Collect Result_Fill2  \
# 0                              NaN                              1
# 1                              NaN                              0
# 2                              NaN                              1
# 3                              NaN                              0
# 4                              NaN                              0
# ...                            ...                            ...
# 40501                          NaN                              0
# 40502                          NaN                              1
# 40503                          NaN                              1
# 40504                          NaN                              0
# 40505                          NaN                              0
#
#        WorkMode Unit Time_Fill2  WorkMode Judge Value_Fill2    target
# 0                           NaN                         NaN    Normal
# 1                           NaN                         NaN    Normal
# 2                           NaN                         NaN    Normal
# 3                           NaN                         NaN    Normal
# 4                           NaN                         NaN    Normal
# ...                         ...                         ...       ...
# 40501                       NaN                         NaN    Normal
# 40502                       NaN                         NaN    Normal
# 40503                       NaN                         NaN    Normal
# 40504                       NaN                         NaN    Normal
# 40505                       NaN                         NaN  AbNormal
#
# [40506 rows x 464 columns]

# %%
import pandas as pd

ROOT_DIR = "data"
df = pd.read_csv(os.path.join(ROOT_DIR, "train.csv"))
df.dropna(axis=1, how='all', inplace=True)

"""
Data process part 
"""

output_path = 'data/train_null.csv'
df.to_csv(output_path, index=False)
print(f"Processed data saved to {output_path}")
# Out:
# Processed data saved to data/train_null.csv

# %% [markdown]
# ### 언더 샘플링

# %% [markdown]
# 데이타 불균형을 해결하기 위해 언더 샘플링을 진행합니다.

# %%
normal_ratio = 1.0  # 1.0 means 1:1 ratio

df_normal = train_data[train_data["target"] == "Normal"]
df_abnormal = train_data[train_data["target"] == "AbNormal"]

num_normal = len(df_normal)
num_abnormal = len(df_abnormal)
print(f"  Total: Normal: {num_normal}, AbNormal: {num_abnormal}")

df_normal = df_normal.sample(n=int(num_abnormal * normal_ratio), replace=False, random_state=RANDOM_STATE)
df_concat = pd.concat([df_normal, df_abnormal], axis=0).reset_index(drop=True)
df_concat.value_counts("target")
# Out:
#   Total: Normal: 38156, AbNormal: 2350
# target
# AbNormal    2350
# Normal      2350
# Name: count, dtype: int64

# %% [markdown]
# ### 데이터 전처리

# %%
#PART 1. Exclude columns where all values are the same and where every value is unique for each row 
def preprocess_unique_value(df):
    #Identify columns where all values are the same
    same_rows_columns = [column for column in df.columns if df[column].nunique() == 0]
    
    #Identify columns where every row's value is unique 
    row_count = len(df) 
##unique_rows_exclude = ['']
    matching_row_columns = [column for column in df.columns if df[column].nunique() == row_count]

    #Exclude specific columns from the unique value check 
    matching_row_columns = [column for column in matching_row_columns if column not in unique_rows_exclude]

    #Drop columns identified in the above steps 
    df.drop(columns=same_rows_columns + matching_row_columns, inplace=True)

    return df

# %%
#PART 2. Remove the features with high correlation
#It looks for columns with identical distribution of unique values and checks for identical mappings between these values 
def reduce_dataframe(df):
#2-1. Get the ratio of the unique values in the given series as a sorted array
    def get_value_counts_ratio(series):
        value_counts = series.value_counts(normalize=True) 
        return value_counts.sort_values().values 

#2-2. Check if there's identical mapping between the unique values of two columns 
# Returns 'true' if one unique value in 'col1' maps to one unique value in 'col2'
    def check_value_mapping(df, col1, col2):
        unique_column_1 = df[col1].unique()
        unique_column_2 = df[col2].unique()

        if len(unique_column_1) != len(unique_column_2) : return False

        value_mapping = {}
        #Check if there's consistent mapping between values in col1 and col2 
        #maybe needs some margin??
        for val1 in unique_column_1:
            consistent_values = df[df[col1] == val1][col2].unique()
            if len(consistent_values) != 1 : 
                return False
            value_mapping [val1] = consistent_values[0]
        
        #Check if there's matching proportion of occurences of values in col1 and col2
        for val1 in unique_column_1: 
            ratio_1 = (df[col1] == val1).mean()
            ratio_2 = (df[col2] == value_mapping[val1]).mean()
            if ratio_1 != ratio_2:
                return False

        return True

#2-3. Idenify columns to remove 
    def compare_all_features(df):
        #Calculate Ratios 
        ratios = {column: get_value_counts_ratio(df[column]) for column in df.columns}
        similar_columns_dict = {column: [] for column in df.columns}

        #Update 'similar_columns_dict' with columns having identical ratios
        columns = list(ratios.keys())
        for i in range(len(columns)):
            for j in range(i + 1, len(columns)):
                if np.array_equal(ratios[columns[i]], ratios[columns[j]]):
                    similar_columns_dict[columns[i]].append(columns[j])

        #Update 'comparisions' fro identical value mappings among columns with similar ratios
        comparisons = []
        for key, values in similar_columns_dict.items():
            for value in values:
                if check_value_mapping(df, key, value):
                    comparisons.append((key, value))
                    

        if comparisons:
            print("다음 피쳐 쌍은 고유값 비율과 양상이 동일합니다:")
            for base, compare in comparisons:
                print(f"'{base}'와(과) '{compare}'")
        else:
            print("모든 피쳐의 고유값 비율과 양상이 동일하지 않습니다.")

        return comparisons

    comparisons = compare_all_features(df)
    columns_to_remove = set()
    for _, col_to_remove in comparisons:
        columns_to_remove.add(col_to_remove)

    df = df.drop(columns=columns_to_remove)
    global df_columns
    df_columns = df.columns
    return df

# %%
def preprocess_train_dataframe(df):
    df = preprocess_unique_value(df)
    df = reduce_dataframe(df)
    return df

# %%
# Add part
df_p = pd.read_csv('data/train_null.csv')
df_pre = preprocess_train_dataframe(df_p)
df_pre.head(2)
pre_path = 'data/train_preprocess.csv'
df_pre.to_csv(pre_path, index=False)
# Out:
# 다음 피쳐 쌍은 고유값 비율과 양상이 동일합니다:
# 'Wip Line_Dam'와(과) 'Process Desc._Dam'
# 'Wip Line_Dam'와(과) 'Insp. Seq No._Dam'
# 'Wip Line_Dam'와(과) 'Insp Judge Code_Dam'
# 'Wip Line_Dam'와(과) 'CURE STANDBY POSITION X Collect Result_Dam'
# 'Wip Line_Dam'와(과) 'CURE STANDBY POSITION Z Collect Result_Dam'
# 'Wip Line_Dam'와(과) 'CURE STANDBY POSITION Θ Collect Result_Dam'
# 'Wip Line_Dam'와(과) 'CURE START POSITION Z Collect Result_Dam'
# 'Wip Line_Dam'와(과) 'Wip Line_AutoClave'
# 'Wip Line_Dam'와(과) 'Process Desc._AutoClave'
# 'Wip Line_Dam'와(과) 'Equipment_AutoClave'
# 'Wip Line_Dam'와(과) 'Insp. Seq No._AutoClave'
# 'Wip Line_Dam'와(과) 'Insp Judge Code_AutoClave'
# 'Wip Line_Dam'와(과) '1st Pressure Judge Value_AutoClave'
# 'Wip Line_Dam'와(과) '2nd Pressure Judge Value_AutoClave'
# 'Wip Line_Dam'와(과) '3rd Pressure Judge Value_AutoClave'
# 'Wip Line_Dam'와(과) 'Wip Line_Fill1'
# 'Wip Line_Dam'와(과) 'Process Desc._Fill1'
# 'Wip Line_Dam'와(과) 'Insp. Seq No._Fill1'
# 'Wip Line_Dam'와(과) 'Insp Judge Code_Fill1'
# 'Wip Line_Dam'와(과) 'Wip Line_Fill2'
# 'Wip Line_Dam'와(과) 'Process Desc._Fill2'
# 'Wip Line_Dam'와(과) 'Insp. Seq No._Fill2'
# 'Wip Line_Dam'와(과) 'Insp Judge Code_Fill2'
# 'Wip Line_Dam'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Wip Line_Dam'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Wip Line_Dam'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Wip Line_Dam'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Wip Line_Dam'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Wip Line_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Wip Line_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Wip Line_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Wip Line_Dam'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Wip Line_Dam'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Wip Line_Dam'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Process Desc._Dam'와(과) 'Insp. Seq No._Dam'
# 'Process Desc._Dam'와(과) 'Insp Judge Code_Dam'
# 'Process Desc._Dam'와(과) 'CURE STANDBY POSITION X Collect Result_Dam'
# 'Process Desc._Dam'와(과) 'CURE STANDBY POSITION Z Collect Result_Dam'
# 'Process Desc._Dam'와(과) 'CURE STANDBY POSITION Θ Collect Result_Dam'
# 'Process Desc._Dam'와(과) 'CURE START POSITION Z Collect Result_Dam'
# 'Process Desc._Dam'와(과) 'Wip Line_AutoClave'
# 'Process Desc._Dam'와(과) 'Process Desc._AutoClave'
# 'Process Desc._Dam'와(과) 'Equipment_AutoClave'
# 'Process Desc._Dam'와(과) 'Insp. Seq No._AutoClave'
# 'Process Desc._Dam'와(과) 'Insp Judge Code_AutoClave'
# 'Process Desc._Dam'와(과) '1st Pressure Judge Value_AutoClave'
# 'Process Desc._Dam'와(과) '2nd Pressure Judge Value_AutoClave'
# 'Process Desc._Dam'와(과) '3rd Pressure Judge Value_AutoClave'
# 'Process Desc._Dam'와(과) 'Wip Line_Fill1'
# 'Process Desc._Dam'와(과) 'Process Desc._Fill1'
# 'Process Desc._Dam'와(과) 'Insp. Seq No._Fill1'
# 'Process Desc._Dam'와(과) 'Insp Judge Code_Fill1'
# 'Process Desc._Dam'와(과) 'Wip Line_Fill2'
# 'Process Desc._Dam'와(과) 'Process Desc._Fill2'
# 'Process Desc._Dam'와(과) 'Insp. Seq No._Fill2'
# 'Process Desc._Dam'와(과) 'Insp Judge Code_Fill2'
# 'Process Desc._Dam'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Process Desc._Dam'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Process Desc._Dam'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Process Desc._Dam'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Process Desc._Dam'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Process Desc._Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Process Desc._Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Process Desc._Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Process Desc._Dam'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Process Desc._Dam'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Process Desc._Dam'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Equipment_Dam'와(과) 'CURE END POSITION X Collect Result_Dam'
# 'Equipment_Dam'와(과) 'CURE END POSITION Z Collect Result_Dam'
# 'Equipment_Dam'와(과) 'CURE END POSITION Θ Collect Result_Dam'
# 'Equipment_Dam'와(과) 'CURE START POSITION X Collect Result_Dam'
# 'Equipment_Dam'와(과) 'CURE START POSITION Θ Collect Result_Dam'
# 'Model.Suffix_Dam'와(과) 'Model.Suffix_AutoClave'
# 'Model.Suffix_Dam'와(과) 'Model.Suffix_Fill1'
# 'Model.Suffix_Dam'와(과) 'Model.Suffix_Fill2'
# 'Workorder_Dam'와(과) 'Workorder_AutoClave'
# 'Workorder_Dam'와(과) 'Workorder_Fill1'
# 'Workorder_Dam'와(과) 'Workorder_Fill2'
# 'Insp. Seq No._Dam'와(과) 'Insp Judge Code_Dam'
# 'Insp. Seq No._Dam'와(과) 'CURE STANDBY POSITION X Collect Result_Dam'
# 'Insp. Seq No._Dam'와(과) 'CURE STANDBY POSITION Z Collect Result_Dam'
# 'Insp. Seq No._Dam'와(과) 'CURE STANDBY POSITION Θ Collect Result_Dam'
# 'Insp. Seq No._Dam'와(과) 'CURE START POSITION Z Collect Result_Dam'
# 'Insp. Seq No._Dam'와(과) 'Wip Line_AutoClave'
# 'Insp. Seq No._Dam'와(과) 'Process Desc._AutoClave'
# 'Insp. Seq No._Dam'와(과) 'Equipment_AutoClave'
# 'Insp. Seq No._Dam'와(과) 'Insp. Seq No._AutoClave'
# 'Insp. Seq No._Dam'와(과) 'Insp Judge Code_AutoClave'
# 'Insp. Seq No._Dam'와(과) '1st Pressure Judge Value_AutoClave'
# 'Insp. Seq No._Dam'와(과) '2nd Pressure Judge Value_AutoClave'
# 'Insp. Seq No._Dam'와(과) '3rd Pressure Judge Value_AutoClave'
# 'Insp. Seq No._Dam'와(과) 'Wip Line_Fill1'
# 'Insp. Seq No._Dam'와(과) 'Process Desc._Fill1'
# 'Insp. Seq No._Dam'와(과) 'Insp. Seq No._Fill1'
# 'Insp. Seq No._Dam'와(과) 'Insp Judge Code_Fill1'
# 'Insp. Seq No._Dam'와(과) 'Wip Line_Fill2'
# 'Insp. Seq No._Dam'와(과) 'Process Desc._Fill2'
# 'Insp. Seq No._Dam'와(과) 'Insp. Seq No._Fill2'
# 'Insp. Seq No._Dam'와(과) 'Insp Judge Code_Fill2'
# 'Insp. Seq No._Dam'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Insp. Seq No._Dam'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Insp. Seq No._Dam'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Insp. Seq No._Dam'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Insp. Seq No._Dam'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Insp. Seq No._Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Insp. Seq No._Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Insp. Seq No._Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Insp. Seq No._Dam'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Insp. Seq No._Dam'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Insp. Seq No._Dam'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Insp Judge Code_Dam'와(과) 'CURE STANDBY POSITION X Collect Result_Dam'
# 'Insp Judge Code_Dam'와(과) 'CURE STANDBY POSITION Z Collect Result_Dam'
# 'Insp Judge Code_Dam'와(과) 'CURE STANDBY POSITION Θ Collect Result_Dam'
# 'Insp Judge Code_Dam'와(과) 'CURE START POSITION Z Collect Result_Dam'
# 'Insp Judge Code_Dam'와(과) 'Wip Line_AutoClave'
# 'Insp Judge Code_Dam'와(과) 'Process Desc._AutoClave'
# 'Insp Judge Code_Dam'와(과) 'Equipment_AutoClave'
# 'Insp Judge Code_Dam'와(과) 'Insp. Seq No._AutoClave'
# 'Insp Judge Code_Dam'와(과) 'Insp Judge Code_AutoClave'
# 'Insp Judge Code_Dam'와(과) '1st Pressure Judge Value_AutoClave'
# 'Insp Judge Code_Dam'와(과) '2nd Pressure Judge Value_AutoClave'
# 'Insp Judge Code_Dam'와(과) '3rd Pressure Judge Value_AutoClave'
# 'Insp Judge Code_Dam'와(과) 'Wip Line_Fill1'
# 'Insp Judge Code_Dam'와(과) 'Process Desc._Fill1'
# 'Insp Judge Code_Dam'와(과) 'Insp. Seq No._Fill1'
# 'Insp Judge Code_Dam'와(과) 'Insp Judge Code_Fill1'
# 'Insp Judge Code_Dam'와(과) 'Wip Line_Fill2'
# 'Insp Judge Code_Dam'와(과) 'Process Desc._Fill2'
# 'Insp Judge Code_Dam'와(과) 'Insp. Seq No._Fill2'
# 'Insp Judge Code_Dam'와(과) 'Insp Judge Code_Fill2'
# 'Insp Judge Code_Dam'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Insp Judge Code_Dam'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Insp Judge Code_Dam'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Insp Judge Code_Dam'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Insp Judge Code_Dam'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Insp Judge Code_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Insp Judge Code_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Insp Judge Code_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Insp Judge Code_Dam'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Insp Judge Code_Dam'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Insp Judge Code_Dam'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'CURE END POSITION X Collect Result_Dam'와(과) 'CURE END POSITION Z Collect Result_Dam'
# 'CURE END POSITION X Collect Result_Dam'와(과) 'CURE END POSITION Θ Collect Result_Dam'
# 'CURE END POSITION X Collect Result_Dam'와(과) 'CURE START POSITION X Collect Result_Dam'
# 'CURE END POSITION X Collect Result_Dam'와(과) 'CURE START POSITION Θ Collect Result_Dam'
# 'CURE END POSITION Z Collect Result_Dam'와(과) 'CURE END POSITION Θ Collect Result_Dam'
# 'CURE END POSITION Z Collect Result_Dam'와(과) 'CURE START POSITION X Collect Result_Dam'
# 'CURE END POSITION Z Collect Result_Dam'와(과) 'CURE START POSITION Θ Collect Result_Dam'
# 'CURE END POSITION Θ Collect Result_Dam'와(과) 'CURE START POSITION X Collect Result_Dam'
# 'CURE END POSITION Θ Collect Result_Dam'와(과) 'CURE START POSITION Θ Collect Result_Dam'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'CURE STANDBY POSITION Z Collect Result_Dam'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'CURE STANDBY POSITION Θ Collect Result_Dam'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'CURE START POSITION Z Collect Result_Dam'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Wip Line_AutoClave'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Process Desc._AutoClave'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Equipment_AutoClave'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Insp. Seq No._AutoClave'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Insp Judge Code_AutoClave'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) '1st Pressure Judge Value_AutoClave'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) '2nd Pressure Judge Value_AutoClave'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) '3rd Pressure Judge Value_AutoClave'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Wip Line_Fill1'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Process Desc._Fill1'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Insp. Seq No._Fill1'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Insp Judge Code_Fill1'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Wip Line_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Process Desc._Fill2'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Insp. Seq No._Fill2'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Insp Judge Code_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Dam'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'CURE STANDBY POSITION Θ Collect Result_Dam'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'CURE START POSITION Z Collect Result_Dam'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Wip Line_AutoClave'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Process Desc._AutoClave'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Equipment_AutoClave'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Insp. Seq No._AutoClave'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Insp Judge Code_AutoClave'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) '1st Pressure Judge Value_AutoClave'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) '2nd Pressure Judge Value_AutoClave'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) '3rd Pressure Judge Value_AutoClave'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Wip Line_Fill1'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Process Desc._Fill1'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Insp. Seq No._Fill1'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Insp Judge Code_Fill1'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Wip Line_Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Process Desc._Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Insp. Seq No._Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Insp Judge Code_Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Dam'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'CURE START POSITION Z Collect Result_Dam'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Wip Line_AutoClave'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Process Desc._AutoClave'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Equipment_AutoClave'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Insp. Seq No._AutoClave'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Insp Judge Code_AutoClave'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) '1st Pressure Judge Value_AutoClave'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) '2nd Pressure Judge Value_AutoClave'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) '3rd Pressure Judge Value_AutoClave'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Wip Line_Fill1'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Process Desc._Fill1'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Insp. Seq No._Fill1'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Insp Judge Code_Fill1'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Wip Line_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Process Desc._Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Insp. Seq No._Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Insp Judge Code_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Dam'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'CURE START POSITION X Collect Result_Dam'와(과) 'CURE START POSITION Θ Collect Result_Dam'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Wip Line_AutoClave'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Process Desc._AutoClave'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Equipment_AutoClave'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Insp. Seq No._AutoClave'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Insp Judge Code_AutoClave'
# 'CURE START POSITION Z Collect Result_Dam'와(과) '1st Pressure Judge Value_AutoClave'
# 'CURE START POSITION Z Collect Result_Dam'와(과) '2nd Pressure Judge Value_AutoClave'
# 'CURE START POSITION Z Collect Result_Dam'와(과) '3rd Pressure Judge Value_AutoClave'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Wip Line_Fill1'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Process Desc._Fill1'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Insp. Seq No._Fill1'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Insp Judge Code_Fill1'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Wip Line_Fill2'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Process Desc._Fill2'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Insp. Seq No._Fill2'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Insp Judge Code_Fill2'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'CURE START POSITION Z Collect Result_Dam'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Dam'와(과) 'HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Dam'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'HEAD Standby Position Z Collect Result_Dam'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'Head Clean Position X Collect Result_Dam'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'Head Clean Position Y Collect Result_Dam'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Dam'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'Head Zero Position X Collect Result_Dam'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'HEAD Standby Position Y Collect Result_Fill1'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'HEAD Standby Position Z Collect Result_Fill1'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'Head Clean Position X Collect Result_Fill1'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'Head Clean Position Y Collect Result_Fill1'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'Head Clean Position Z Collect Result_Fill1'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'Head Purge Position X Collect Result_Fill1'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Fill1'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'HEAD Standby Position Y Collect Result_Fill2'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'HEAD Standby Position Z Collect Result_Fill2'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'Head Clean Position X Collect Result_Fill2'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'Head Clean Position Y Collect Result_Fill2'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'Head Clean Position Z Collect Result_Fill2'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'Head Purge Position X Collect Result_Fill2'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Fill2'
# 'HEAD Standby Position Y Collect Result_Dam'와(과) 'Head Purge Position Z Collect Result_Fill2'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'Head Clean Position X Collect Result_Dam'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'Head Clean Position Y Collect Result_Dam'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Dam'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'Head Zero Position X Collect Result_Dam'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'HEAD Standby Position Y Collect Result_Fill1'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'HEAD Standby Position Z Collect Result_Fill1'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'Head Clean Position X Collect Result_Fill1'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'Head Clean Position Y Collect Result_Fill1'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'Head Clean Position Z Collect Result_Fill1'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'Head Purge Position X Collect Result_Fill1'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Fill1'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'HEAD Standby Position Y Collect Result_Fill2'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'HEAD Standby Position Z Collect Result_Fill2'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'Head Clean Position X Collect Result_Fill2'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'Head Clean Position Y Collect Result_Fill2'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'Head Clean Position Z Collect Result_Fill2'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'Head Purge Position X Collect Result_Fill2'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Fill2'
# 'HEAD Standby Position Z Collect Result_Dam'와(과) 'Head Purge Position Z Collect Result_Fill2'
# 'Head Clean Position X Collect Result_Dam'와(과) 'Head Clean Position Y Collect Result_Dam'
# 'Head Clean Position X Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Dam'
# 'Head Clean Position X Collect Result_Dam'와(과) 'Head Zero Position X Collect Result_Dam'
# 'Head Clean Position X Collect Result_Dam'와(과) 'HEAD Standby Position Y Collect Result_Fill1'
# 'Head Clean Position X Collect Result_Dam'와(과) 'HEAD Standby Position Z Collect Result_Fill1'
# 'Head Clean Position X Collect Result_Dam'와(과) 'Head Clean Position X Collect Result_Fill1'
# 'Head Clean Position X Collect Result_Dam'와(과) 'Head Clean Position Y Collect Result_Fill1'
# 'Head Clean Position X Collect Result_Dam'와(과) 'Head Clean Position Z Collect Result_Fill1'
# 'Head Clean Position X Collect Result_Dam'와(과) 'Head Purge Position X Collect Result_Fill1'
# 'Head Clean Position X Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Fill1'
# 'Head Clean Position X Collect Result_Dam'와(과) 'HEAD Standby Position Y Collect Result_Fill2'
# 'Head Clean Position X Collect Result_Dam'와(과) 'HEAD Standby Position Z Collect Result_Fill2'
# 'Head Clean Position X Collect Result_Dam'와(과) 'Head Clean Position X Collect Result_Fill2'
# 'Head Clean Position X Collect Result_Dam'와(과) 'Head Clean Position Y Collect Result_Fill2'
# 'Head Clean Position X Collect Result_Dam'와(과) 'Head Clean Position Z Collect Result_Fill2'
# 'Head Clean Position X Collect Result_Dam'와(과) 'Head Purge Position X Collect Result_Fill2'
# 'Head Clean Position X Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Fill2'
# 'Head Clean Position X Collect Result_Dam'와(과) 'Head Purge Position Z Collect Result_Fill2'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Dam'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'Head Zero Position X Collect Result_Dam'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'HEAD Standby Position Y Collect Result_Fill1'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'HEAD Standby Position Z Collect Result_Fill1'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'Head Clean Position X Collect Result_Fill1'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'Head Clean Position Y Collect Result_Fill1'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'Head Clean Position Z Collect Result_Fill1'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'Head Purge Position X Collect Result_Fill1'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Fill1'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'HEAD Standby Position Y Collect Result_Fill2'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'HEAD Standby Position Z Collect Result_Fill2'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'Head Clean Position X Collect Result_Fill2'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'Head Clean Position Y Collect Result_Fill2'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'Head Clean Position Z Collect Result_Fill2'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'Head Purge Position X Collect Result_Fill2'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Fill2'
# 'Head Clean Position Y Collect Result_Dam'와(과) 'Head Purge Position Z Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'Head Zero Position X Collect Result_Dam'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'HEAD Standby Position Y Collect Result_Fill1'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'HEAD Standby Position Z Collect Result_Fill1'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'Head Clean Position X Collect Result_Fill1'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'Head Clean Position Y Collect Result_Fill1'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'Head Clean Position Z Collect Result_Fill1'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'Head Purge Position X Collect Result_Fill1'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Fill1'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'HEAD Standby Position Y Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'HEAD Standby Position Z Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'Head Clean Position X Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'Head Clean Position Y Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'Head Clean Position Z Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'Head Purge Position X Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Dam'와(과) 'Head Purge Position Z Collect Result_Fill2'
# 'Head Zero Position X Collect Result_Dam'와(과) 'HEAD Standby Position Y Collect Result_Fill1'
# 'Head Zero Position X Collect Result_Dam'와(과) 'HEAD Standby Position Z Collect Result_Fill1'
# 'Head Zero Position X Collect Result_Dam'와(과) 'Head Clean Position X Collect Result_Fill1'
# 'Head Zero Position X Collect Result_Dam'와(과) 'Head Clean Position Y Collect Result_Fill1'
# 'Head Zero Position X Collect Result_Dam'와(과) 'Head Clean Position Z Collect Result_Fill1'
# 'Head Zero Position X Collect Result_Dam'와(과) 'Head Purge Position X Collect Result_Fill1'
# 'Head Zero Position X Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Fill1'
# 'Head Zero Position X Collect Result_Dam'와(과) 'HEAD Standby Position Y Collect Result_Fill2'
# 'Head Zero Position X Collect Result_Dam'와(과) 'HEAD Standby Position Z Collect Result_Fill2'
# 'Head Zero Position X Collect Result_Dam'와(과) 'Head Clean Position X Collect Result_Fill2'
# 'Head Zero Position X Collect Result_Dam'와(과) 'Head Clean Position Y Collect Result_Fill2'
# 'Head Zero Position X Collect Result_Dam'와(과) 'Head Clean Position Z Collect Result_Fill2'
# 'Head Zero Position X Collect Result_Dam'와(과) 'Head Purge Position X Collect Result_Fill2'
# 'Head Zero Position X Collect Result_Dam'와(과) 'Head Purge Position Y Collect Result_Fill2'
# 'Head Zero Position X Collect Result_Dam'와(과) 'Head Purge Position Z Collect Result_Fill2'
# 'Stage1 Circle2 Distance Speed Collect Result_Dam'와(과) 'Stage1 Circle3 Distance Speed Collect Result_Dam'
# 'Stage1 Circle2 Distance Speed Collect Result_Dam'와(과) 'Stage1 Circle4 Distance Speed Collect Result_Dam'
# 'Stage1 Circle3 Distance Speed Collect Result_Dam'와(과) 'Stage1 Circle4 Distance Speed Collect Result_Dam'
# 'Stage1 Line1 Distance Speed Collect Result_Dam'와(과) 'Stage1 Line3 Distance Speed Collect Result_Dam'
# 'Stage2 Circle2 Distance Speed Collect Result_Dam'와(과) 'Stage2 Circle3 Distance Speed Collect Result_Dam'
# 'Stage2 Circle2 Distance Speed Collect Result_Dam'와(과) 'Stage2 Circle4 Distance Speed Collect Result_Dam'
# 'Stage2 Circle2 Distance Speed Collect Result_Dam'와(과) 'Stage2 Line1 Distance Speed Collect Result_Dam'
# 'Stage2 Circle3 Distance Speed Collect Result_Dam'와(과) 'Stage2 Circle4 Distance Speed Collect Result_Dam'
# 'Stage2 Circle3 Distance Speed Collect Result_Dam'와(과) 'Stage2 Line1 Distance Speed Collect Result_Dam'
# 'Stage2 Circle4 Distance Speed Collect Result_Dam'와(과) 'Stage2 Line1 Distance Speed Collect Result_Dam'
# 'Stage3 Circle2 Distance Speed Collect Result_Dam'와(과) 'Stage3 Circle3 Distance Speed Collect Result_Dam'
# 'Stage3 Circle2 Distance Speed Collect Result_Dam'와(과) 'Stage3 Circle4 Distance Speed Collect Result_Dam'
# 'Stage3 Circle3 Distance Speed Collect Result_Dam'와(과) 'Stage3 Circle4 Distance Speed Collect Result_Dam'
# 'Stage3 Line1 Distance Speed Collect Result_Dam'와(과) 'Stage3 Line3 Distance Speed Collect Result_Dam'
# 'Wip Line_AutoClave'와(과) 'Process Desc._AutoClave'
# 'Wip Line_AutoClave'와(과) 'Equipment_AutoClave'
# 'Wip Line_AutoClave'와(과) 'Insp. Seq No._AutoClave'
# 'Wip Line_AutoClave'와(과) 'Insp Judge Code_AutoClave'
# 'Wip Line_AutoClave'와(과) '1st Pressure Judge Value_AutoClave'
# 'Wip Line_AutoClave'와(과) '2nd Pressure Judge Value_AutoClave'
# 'Wip Line_AutoClave'와(과) '3rd Pressure Judge Value_AutoClave'
# 'Wip Line_AutoClave'와(과) 'Wip Line_Fill1'
# 'Wip Line_AutoClave'와(과) 'Process Desc._Fill1'
# 'Wip Line_AutoClave'와(과) 'Insp. Seq No._Fill1'
# 'Wip Line_AutoClave'와(과) 'Insp Judge Code_Fill1'
# 'Wip Line_AutoClave'와(과) 'Wip Line_Fill2'
# 'Wip Line_AutoClave'와(과) 'Process Desc._Fill2'
# 'Wip Line_AutoClave'와(과) 'Insp. Seq No._Fill2'
# 'Wip Line_AutoClave'와(과) 'Insp Judge Code_Fill2'
# 'Wip Line_AutoClave'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Wip Line_AutoClave'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Wip Line_AutoClave'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Wip Line_AutoClave'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Wip Line_AutoClave'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Wip Line_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Wip Line_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Wip Line_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Wip Line_AutoClave'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Wip Line_AutoClave'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Wip Line_AutoClave'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Process Desc._AutoClave'와(과) 'Equipment_AutoClave'
# 'Process Desc._AutoClave'와(과) 'Insp. Seq No._AutoClave'
# 'Process Desc._AutoClave'와(과) 'Insp Judge Code_AutoClave'
# 'Process Desc._AutoClave'와(과) '1st Pressure Judge Value_AutoClave'
# 'Process Desc._AutoClave'와(과) '2nd Pressure Judge Value_AutoClave'
# 'Process Desc._AutoClave'와(과) '3rd Pressure Judge Value_AutoClave'
# 'Process Desc._AutoClave'와(과) 'Wip Line_Fill1'
# 'Process Desc._AutoClave'와(과) 'Process Desc._Fill1'
# 'Process Desc._AutoClave'와(과) 'Insp. Seq No._Fill1'
# 'Process Desc._AutoClave'와(과) 'Insp Judge Code_Fill1'
# 'Process Desc._AutoClave'와(과) 'Wip Line_Fill2'
# 'Process Desc._AutoClave'와(과) 'Process Desc._Fill2'
# 'Process Desc._AutoClave'와(과) 'Insp. Seq No._Fill2'
# 'Process Desc._AutoClave'와(과) 'Insp Judge Code_Fill2'
# 'Process Desc._AutoClave'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Process Desc._AutoClave'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Process Desc._AutoClave'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Process Desc._AutoClave'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Process Desc._AutoClave'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Process Desc._AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Process Desc._AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Process Desc._AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Process Desc._AutoClave'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Process Desc._AutoClave'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Process Desc._AutoClave'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Equipment_AutoClave'와(과) 'Insp. Seq No._AutoClave'
# 'Equipment_AutoClave'와(과) 'Insp Judge Code_AutoClave'
# 'Equipment_AutoClave'와(과) '1st Pressure Judge Value_AutoClave'
# 'Equipment_AutoClave'와(과) '2nd Pressure Judge Value_AutoClave'
# 'Equipment_AutoClave'와(과) '3rd Pressure Judge Value_AutoClave'
# 'Equipment_AutoClave'와(과) 'Wip Line_Fill1'
# 'Equipment_AutoClave'와(과) 'Process Desc._Fill1'
# 'Equipment_AutoClave'와(과) 'Insp. Seq No._Fill1'
# 'Equipment_AutoClave'와(과) 'Insp Judge Code_Fill1'
# 'Equipment_AutoClave'와(과) 'Wip Line_Fill2'
# 'Equipment_AutoClave'와(과) 'Process Desc._Fill2'
# 'Equipment_AutoClave'와(과) 'Insp. Seq No._Fill2'
# 'Equipment_AutoClave'와(과) 'Insp Judge Code_Fill2'
# 'Equipment_AutoClave'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Equipment_AutoClave'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Equipment_AutoClave'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Equipment_AutoClave'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Equipment_AutoClave'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Equipment_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Equipment_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Equipment_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Equipment_AutoClave'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Equipment_AutoClave'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Equipment_AutoClave'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Model.Suffix_AutoClave'와(과) 'Model.Suffix_Fill1'
# 'Model.Suffix_AutoClave'와(과) 'Model.Suffix_Fill2'
# 'Workorder_AutoClave'와(과) 'Workorder_Fill1'
# 'Workorder_AutoClave'와(과) 'Workorder_Fill2'
# 'Insp. Seq No._AutoClave'와(과) 'Insp Judge Code_AutoClave'
# 'Insp. Seq No._AutoClave'와(과) '1st Pressure Judge Value_AutoClave'
# 'Insp. Seq No._AutoClave'와(과) '2nd Pressure Judge Value_AutoClave'
# 'Insp. Seq No._AutoClave'와(과) '3rd Pressure Judge Value_AutoClave'
# 'Insp. Seq No._AutoClave'와(과) 'Wip Line_Fill1'
# 'Insp. Seq No._AutoClave'와(과) 'Process Desc._Fill1'
# 'Insp. Seq No._AutoClave'와(과) 'Insp. Seq No._Fill1'
# 'Insp. Seq No._AutoClave'와(과) 'Insp Judge Code_Fill1'
# 'Insp. Seq No._AutoClave'와(과) 'Wip Line_Fill2'
# 'Insp. Seq No._AutoClave'와(과) 'Process Desc._Fill2'
# 'Insp. Seq No._AutoClave'와(과) 'Insp. Seq No._Fill2'
# 'Insp. Seq No._AutoClave'와(과) 'Insp Judge Code_Fill2'
# 'Insp. Seq No._AutoClave'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Insp. Seq No._AutoClave'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Insp. Seq No._AutoClave'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Insp. Seq No._AutoClave'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Insp. Seq No._AutoClave'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Insp. Seq No._AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Insp. Seq No._AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Insp. Seq No._AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Insp. Seq No._AutoClave'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Insp. Seq No._AutoClave'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Insp. Seq No._AutoClave'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Insp Judge Code_AutoClave'와(과) '1st Pressure Judge Value_AutoClave'
# 'Insp Judge Code_AutoClave'와(과) '2nd Pressure Judge Value_AutoClave'
# 'Insp Judge Code_AutoClave'와(과) '3rd Pressure Judge Value_AutoClave'
# 'Insp Judge Code_AutoClave'와(과) 'Wip Line_Fill1'
# 'Insp Judge Code_AutoClave'와(과) 'Process Desc._Fill1'
# 'Insp Judge Code_AutoClave'와(과) 'Insp. Seq No._Fill1'
# 'Insp Judge Code_AutoClave'와(과) 'Insp Judge Code_Fill1'
# 'Insp Judge Code_AutoClave'와(과) 'Wip Line_Fill2'
# 'Insp Judge Code_AutoClave'와(과) 'Process Desc._Fill2'
# 'Insp Judge Code_AutoClave'와(과) 'Insp. Seq No._Fill2'
# 'Insp Judge Code_AutoClave'와(과) 'Insp Judge Code_Fill2'
# 'Insp Judge Code_AutoClave'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Insp Judge Code_AutoClave'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Insp Judge Code_AutoClave'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Insp Judge Code_AutoClave'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Insp Judge Code_AutoClave'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Insp Judge Code_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Insp Judge Code_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Insp Judge Code_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Insp Judge Code_AutoClave'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Insp Judge Code_AutoClave'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Insp Judge Code_AutoClave'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# '1st Pressure Judge Value_AutoClave'와(과) '2nd Pressure Judge Value_AutoClave'
# '1st Pressure Judge Value_AutoClave'와(과) '3rd Pressure Judge Value_AutoClave'
# '1st Pressure Judge Value_AutoClave'와(과) 'Wip Line_Fill1'
# '1st Pressure Judge Value_AutoClave'와(과) 'Process Desc._Fill1'
# '1st Pressure Judge Value_AutoClave'와(과) 'Insp. Seq No._Fill1'
# '1st Pressure Judge Value_AutoClave'와(과) 'Insp Judge Code_Fill1'
# '1st Pressure Judge Value_AutoClave'와(과) 'Wip Line_Fill2'
# '1st Pressure Judge Value_AutoClave'와(과) 'Process Desc._Fill2'
# '1st Pressure Judge Value_AutoClave'와(과) 'Insp. Seq No._Fill2'
# '1st Pressure Judge Value_AutoClave'와(과) 'Insp Judge Code_Fill2'
# '1st Pressure Judge Value_AutoClave'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# '1st Pressure Judge Value_AutoClave'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# '1st Pressure Judge Value_AutoClave'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# '1st Pressure Judge Value_AutoClave'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# '1st Pressure Judge Value_AutoClave'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# '1st Pressure Judge Value_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# '1st Pressure Judge Value_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# '1st Pressure Judge Value_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# '1st Pressure Judge Value_AutoClave'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# '1st Pressure Judge Value_AutoClave'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# '1st Pressure Judge Value_AutoClave'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# '2nd Pressure Judge Value_AutoClave'와(과) '3rd Pressure Judge Value_AutoClave'
# '2nd Pressure Judge Value_AutoClave'와(과) 'Wip Line_Fill1'
# '2nd Pressure Judge Value_AutoClave'와(과) 'Process Desc._Fill1'
# '2nd Pressure Judge Value_AutoClave'와(과) 'Insp. Seq No._Fill1'
# '2nd Pressure Judge Value_AutoClave'와(과) 'Insp Judge Code_Fill1'
# '2nd Pressure Judge Value_AutoClave'와(과) 'Wip Line_Fill2'
# '2nd Pressure Judge Value_AutoClave'와(과) 'Process Desc._Fill2'
# '2nd Pressure Judge Value_AutoClave'와(과) 'Insp. Seq No._Fill2'
# '2nd Pressure Judge Value_AutoClave'와(과) 'Insp Judge Code_Fill2'
# '2nd Pressure Judge Value_AutoClave'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# '2nd Pressure Judge Value_AutoClave'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# '2nd Pressure Judge Value_AutoClave'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# '2nd Pressure Judge Value_AutoClave'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# '2nd Pressure Judge Value_AutoClave'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# '2nd Pressure Judge Value_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# '2nd Pressure Judge Value_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# '2nd Pressure Judge Value_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# '2nd Pressure Judge Value_AutoClave'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# '2nd Pressure Judge Value_AutoClave'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# '2nd Pressure Judge Value_AutoClave'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# '3rd Pressure Judge Value_AutoClave'와(과) 'Wip Line_Fill1'
# '3rd Pressure Judge Value_AutoClave'와(과) 'Process Desc._Fill1'
# '3rd Pressure Judge Value_AutoClave'와(과) 'Insp. Seq No._Fill1'
# '3rd Pressure Judge Value_AutoClave'와(과) 'Insp Judge Code_Fill1'
# '3rd Pressure Judge Value_AutoClave'와(과) 'Wip Line_Fill2'
# '3rd Pressure Judge Value_AutoClave'와(과) 'Process Desc._Fill2'
# '3rd Pressure Judge Value_AutoClave'와(과) 'Insp. Seq No._Fill2'
# '3rd Pressure Judge Value_AutoClave'와(과) 'Insp Judge Code_Fill2'
# '3rd Pressure Judge Value_AutoClave'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# '3rd Pressure Judge Value_AutoClave'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# '3rd Pressure Judge Value_AutoClave'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# '3rd Pressure Judge Value_AutoClave'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# '3rd Pressure Judge Value_AutoClave'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# '3rd Pressure Judge Value_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# '3rd Pressure Judge Value_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# '3rd Pressure Judge Value_AutoClave'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# '3rd Pressure Judge Value_AutoClave'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# '3rd Pressure Judge Value_AutoClave'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# '3rd Pressure Judge Value_AutoClave'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Wip Line_Fill1'와(과) 'Process Desc._Fill1'
# 'Wip Line_Fill1'와(과) 'Insp. Seq No._Fill1'
# 'Wip Line_Fill1'와(과) 'Insp Judge Code_Fill1'
# 'Wip Line_Fill1'와(과) 'Wip Line_Fill2'
# 'Wip Line_Fill1'와(과) 'Process Desc._Fill2'
# 'Wip Line_Fill1'와(과) 'Insp. Seq No._Fill2'
# 'Wip Line_Fill1'와(과) 'Insp Judge Code_Fill2'
# 'Wip Line_Fill1'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Wip Line_Fill1'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Wip Line_Fill1'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Wip Line_Fill1'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Wip Line_Fill1'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Wip Line_Fill1'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Wip Line_Fill1'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Wip Line_Fill1'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Wip Line_Fill1'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Wip Line_Fill1'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Wip Line_Fill1'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Process Desc._Fill1'와(과) 'Insp. Seq No._Fill1'
# 'Process Desc._Fill1'와(과) 'Insp Judge Code_Fill1'
# 'Process Desc._Fill1'와(과) 'Wip Line_Fill2'
# 'Process Desc._Fill1'와(과) 'Process Desc._Fill2'
# 'Process Desc._Fill1'와(과) 'Insp. Seq No._Fill2'
# 'Process Desc._Fill1'와(과) 'Insp Judge Code_Fill2'
# 'Process Desc._Fill1'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Process Desc._Fill1'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Process Desc._Fill1'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Process Desc._Fill1'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Process Desc._Fill1'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Process Desc._Fill1'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Process Desc._Fill1'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Process Desc._Fill1'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Process Desc._Fill1'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Process Desc._Fill1'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Process Desc._Fill1'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Model.Suffix_Fill1'와(과) 'Model.Suffix_Fill2'
# 'Workorder_Fill1'와(과) 'Workorder_Fill2'
# 'Insp. Seq No._Fill1'와(과) 'Insp Judge Code_Fill1'
# 'Insp. Seq No._Fill1'와(과) 'Wip Line_Fill2'
# 'Insp. Seq No._Fill1'와(과) 'Process Desc._Fill2'
# 'Insp. Seq No._Fill1'와(과) 'Insp. Seq No._Fill2'
# 'Insp. Seq No._Fill1'와(과) 'Insp Judge Code_Fill2'
# 'Insp. Seq No._Fill1'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Insp. Seq No._Fill1'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Insp. Seq No._Fill1'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Insp. Seq No._Fill1'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Insp. Seq No._Fill1'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Insp. Seq No._Fill1'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Insp. Seq No._Fill1'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Insp. Seq No._Fill1'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Insp. Seq No._Fill1'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Insp. Seq No._Fill1'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Insp. Seq No._Fill1'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Insp Judge Code_Fill1'와(과) 'Wip Line_Fill2'
# 'Insp Judge Code_Fill1'와(과) 'Process Desc._Fill2'
# 'Insp Judge Code_Fill1'와(과) 'Insp. Seq No._Fill2'
# 'Insp Judge Code_Fill1'와(과) 'Insp Judge Code_Fill2'
# 'Insp Judge Code_Fill1'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Insp Judge Code_Fill1'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Insp Judge Code_Fill1'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Insp Judge Code_Fill1'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Insp Judge Code_Fill1'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Insp Judge Code_Fill1'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Insp Judge Code_Fill1'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Insp Judge Code_Fill1'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Insp Judge Code_Fill1'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Insp Judge Code_Fill1'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Insp Judge Code_Fill1'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1'와(과) 'Dispense Volume(Stage1) Collect Result_Fill1'
# 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1'와(과) 'Dispense Volume(Stage3) Collect Result_Fill1'
# 'HEAD Standby Position Y Collect Result_Fill1'와(과) 'HEAD Standby Position Z Collect Result_Fill1'
# 'HEAD Standby Position Y Collect Result_Fill1'와(과) 'Head Clean Position X Collect Result_Fill1'
# 'HEAD Standby Position Y Collect Result_Fill1'와(과) 'Head Clean Position Y Collect Result_Fill1'
# 'HEAD Standby Position Y Collect Result_Fill1'와(과) 'Head Clean Position Z Collect Result_Fill1'
# 'HEAD Standby Position Y Collect Result_Fill1'와(과) 'Head Purge Position X Collect Result_Fill1'
# 'HEAD Standby Position Y Collect Result_Fill1'와(과) 'Head Purge Position Y Collect Result_Fill1'
# 'HEAD Standby Position Y Collect Result_Fill1'와(과) 'HEAD Standby Position Y Collect Result_Fill2'
# ...
# 'Head Purge Position Y Collect Result_Fill1'와(과) 'HEAD Standby Position Y Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Fill1'와(과) 'HEAD Standby Position Z Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Fill1'와(과) 'Head Clean Position X Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Fill1'와(과) 'Head Clean Position Y Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Fill1'와(과) 'Head Clean Position Z Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Fill1'와(과) 'Head Purge Position X Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Fill1'와(과) 'Head Purge Position Y Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Fill1'와(과) 'Head Purge Position Z Collect Result_Fill2'
# 'Wip Line_Fill2'와(과) 'Process Desc._Fill2'
# 'Wip Line_Fill2'와(과) 'Insp. Seq No._Fill2'
# 'Wip Line_Fill2'와(과) 'Insp Judge Code_Fill2'
# 'Wip Line_Fill2'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Wip Line_Fill2'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Wip Line_Fill2'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Wip Line_Fill2'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Wip Line_Fill2'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Wip Line_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Wip Line_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Wip Line_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Wip Line_Fill2'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Wip Line_Fill2'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Wip Line_Fill2'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Process Desc._Fill2'와(과) 'Insp. Seq No._Fill2'
# 'Process Desc._Fill2'와(과) 'Insp Judge Code_Fill2'
# 'Process Desc._Fill2'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Process Desc._Fill2'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Process Desc._Fill2'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Process Desc._Fill2'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Process Desc._Fill2'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Process Desc._Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Process Desc._Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Process Desc._Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Process Desc._Fill2'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Process Desc._Fill2'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Process Desc._Fill2'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Equipment_Fill2'와(과) 'HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill2'
# 'Equipment_Fill2'와(과) 'HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill2'
# 'Insp. Seq No._Fill2'와(과) 'Insp Judge Code_Fill2'
# 'Insp. Seq No._Fill2'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Insp. Seq No._Fill2'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Insp. Seq No._Fill2'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Insp. Seq No._Fill2'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Insp. Seq No._Fill2'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Insp. Seq No._Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Insp. Seq No._Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Insp. Seq No._Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Insp. Seq No._Fill2'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Insp. Seq No._Fill2'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Insp. Seq No._Fill2'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Insp Judge Code_Fill2'와(과) 'CURE END POSITION Θ Collect Result_Fill2'
# 'Insp Judge Code_Fill2'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'Insp Judge Code_Fill2'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'Insp Judge Code_Fill2'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'Insp Judge Code_Fill2'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'Insp Judge Code_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'Insp Judge Code_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'Insp Judge Code_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'Insp Judge Code_Fill2'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'Insp Judge Code_Fill2'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Insp Judge Code_Fill2'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'CURE END POSITION X Collect Result_Fill2'와(과) 'CURE START POSITION X Collect Result_Fill2'
# 'CURE END POSITION Θ Collect Result_Fill2'와(과) 'CURE STANDBY POSITION X Collect Result_Fill2'
# 'CURE END POSITION Θ Collect Result_Fill2'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'CURE END POSITION Θ Collect Result_Fill2'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'CURE END POSITION Θ Collect Result_Fill2'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'CURE END POSITION Θ Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'CURE END POSITION Θ Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'CURE END POSITION Θ Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'CURE END POSITION Θ Collect Result_Fill2'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'CURE END POSITION Θ Collect Result_Fill2'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'CURE END POSITION Θ Collect Result_Fill2'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Fill2'와(과) 'CURE STANDBY POSITION Θ Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Fill2'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Fill2'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Fill2'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Fill2'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'CURE STANDBY POSITION X Collect Result_Fill2'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'CURE STANDBY POSITION Z Collect Result_Fill2'와(과) 'CURE START POSITION Z Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Fill2'와(과) 'CURE START POSITION Θ Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Fill2'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Fill2'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Fill2'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'CURE STANDBY POSITION Θ Collect Result_Fill2'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'CURE START POSITION Θ Collect Result_Fill2'와(과) 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'
# 'CURE START POSITION Θ Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'CURE START POSITION Θ Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'CURE START POSITION Θ Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'CURE START POSITION Θ Collect Result_Fill2'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'CURE START POSITION Θ Collect Result_Fill2'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'CURE START POSITION Θ Collect Result_Fill2'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'
# 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'DISCHARGED SPEED OF RESIN Collect Result_Fill2'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'
# 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'와(과) 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'
# 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'와(과) 'Dispense Volume(Stage1) Collect Result_Fill2'
# 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Dispense Volume(Stage1) Collect Result_Fill2'와(과) 'Dispense Volume(Stage2) Collect Result_Fill2'
# 'Dispense Volume(Stage1) Collect Result_Fill2'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'Dispense Volume(Stage2) Collect Result_Fill2'와(과) 'Dispense Volume(Stage3) Collect Result_Fill2'
# 'HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill2'와(과) 'HEAD NORMAL COORDINATE Y AXIS(Stage1) Collect Result_Fill2'
# 'HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill2'와(과) 'HEAD NORMAL COORDINATE Z AXIS(Stage1) Collect Result_Fill2'
# 'HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill2'와(과) 'HEAD NORMAL COORDINATE Y AXIS(Stage3) Collect Result_Fill2'
# 'HEAD NORMAL COORDINATE Z AXIS(Stage2) Collect Result_Fill2'와(과) 'HEAD NORMAL COORDINATE Z AXIS(Stage3) Collect Result_Fill2'
# 'HEAD Standby Position Y Collect Result_Fill2'와(과) 'HEAD Standby Position Z Collect Result_Fill2'
# 'HEAD Standby Position Y Collect Result_Fill2'와(과) 'Head Clean Position X Collect Result_Fill2'
# 'HEAD Standby Position Y Collect Result_Fill2'와(과) 'Head Clean Position Y Collect Result_Fill2'
# 'HEAD Standby Position Y Collect Result_Fill2'와(과) 'Head Clean Position Z Collect Result_Fill2'
# 'HEAD Standby Position Y Collect Result_Fill2'와(과) 'Head Purge Position X Collect Result_Fill2'
# 'HEAD Standby Position Y Collect Result_Fill2'와(과) 'Head Purge Position Y Collect Result_Fill2'
# 'HEAD Standby Position Y Collect Result_Fill2'와(과) 'Head Purge Position Z Collect Result_Fill2'
# 'HEAD Standby Position Z Collect Result_Fill2'와(과) 'Head Clean Position X Collect Result_Fill2'
# 'HEAD Standby Position Z Collect Result_Fill2'와(과) 'Head Clean Position Y Collect Result_Fill2'
# 'HEAD Standby Position Z Collect Result_Fill2'와(과) 'Head Clean Position Z Collect Result_Fill2'
# 'HEAD Standby Position Z Collect Result_Fill2'와(과) 'Head Purge Position X Collect Result_Fill2'
# 'HEAD Standby Position Z Collect Result_Fill2'와(과) 'Head Purge Position Y Collect Result_Fill2'
# 'HEAD Standby Position Z Collect Result_Fill2'와(과) 'Head Purge Position Z Collect Result_Fill2'
# 'Head Clean Position X Collect Result_Fill2'와(과) 'Head Clean Position Y Collect Result_Fill2'
# 'Head Clean Position X Collect Result_Fill2'와(과) 'Head Clean Position Z Collect Result_Fill2'
# 'Head Clean Position X Collect Result_Fill2'와(과) 'Head Purge Position X Collect Result_Fill2'
# 'Head Clean Position X Collect Result_Fill2'와(과) 'Head Purge Position Y Collect Result_Fill2'
# 'Head Clean Position X Collect Result_Fill2'와(과) 'Head Purge Position Z Collect Result_Fill2'
# 'Head Clean Position Y Collect Result_Fill2'와(과) 'Head Clean Position Z Collect Result_Fill2'
# 'Head Clean Position Y Collect Result_Fill2'와(과) 'Head Purge Position X Collect Result_Fill2'
# 'Head Clean Position Y Collect Result_Fill2'와(과) 'Head Purge Position Y Collect Result_Fill2'
# 'Head Clean Position Y Collect Result_Fill2'와(과) 'Head Purge Position Z Collect Result_Fill2'
# 'Head Clean Position Z Collect Result_Fill2'와(과) 'Head Purge Position X Collect Result_Fill2'
# 'Head Clean Position Z Collect Result_Fill2'와(과) 'Head Purge Position Y Collect Result_Fill2'
# 'Head Clean Position Z Collect Result_Fill2'와(과) 'Head Purge Position Z Collect Result_Fill2'
# 'Head Purge Position X Collect Result_Fill2'와(과) 'Head Purge Position Y Collect Result_Fill2'
# 'Head Purge Position X Collect Result_Fill2'와(과) 'Head Purge Position Z Collect Result_Fill2'
# 'Head Purge Position Y Collect Result_Fill2'와(과) 'Head Purge Position Z Collect Result_Fill2'
#   Wip Line_Dam     Equipment_Dam Model.Suffix_Dam Workorder_Dam  \
# 0      IVI-OB6  Dam dispenser #1      AJX75334505    4F1XA938-1
# 1      IVI-OB6  Dam dispenser #1      AJX75334505    3KPM0016-2
#
#    CURE SPEED Collect Result_Dam  \
# 0                            100
# 1                             70
#
#    DISCHARGED SPEED OF RESIN Collect Result_Dam  \
# 0                                            16
# 1                                            10
#
#    DISCHARGED TIME OF RESIN(Stage1) Collect Result_Dam  \
# 0                                               14.9
# 1                                               21.3
#
#    DISCHARGED TIME OF RESIN(Stage2) Collect Result_Dam  \
# 0                                                8.4
# 1                                                4.9
#
#    DISCHARGED TIME OF RESIN(Stage3) Collect Result_Dam  \
# 0                                               14.7
# 1                                               21.3
#
#    Dispense Volume(Stage1) Collect Result_Dam  ...  \
# 0                                        1.04  ...
# 1                                        1.49  ...
#
#    HEAD NORMAL COORDINATE X AXIS(Stage2) Collect Result_Fill2  \
# 0                                              835.5
# 1                                              458.0
#
#    HEAD NORMAL COORDINATE X AXIS(Stage3) Collect Result_Fill2  \
# 0                                              458.0
# 1                                              156.0
#
#   HEAD NORMAL COORDINATE Y AXIS(Stage2) Collect Result_Fill2  \
# 0                                              428.0
# 1                                              427.9
#
#   HEAD Standby Position X Collect Result_Fill2  \
# 0                                        243.7
# 1                                        270.0
#
#    Machine Tact time Collect Result_Fill2  PalletID Collect Result_Fill2  \
# 0                                 114.612                           19.9
# 1                                  19.600                            7.0
#
#    Production Qty Collect Result_Fill2  Receip No Collect Result_Fill2  \
# 0                                    7                             127
# 1                                  185                               1
#
#    WorkMode Collect Result_Fill2  target
# 0                              1  Normal
# 1                              0  Normal
#
# [2 rows x 102 columns]

# %%
pre_path = 'data/train_preprocess.csv'
df_pre.to_csv(pre_path, index=False)

# %%
def is_column_to_drop(col):
    unique_values = col.dropna().unique()
    return len(unique_values) == 0 or (len(unique_values) == 1 and unique_values[0] == 'OK') or set(unique_values) == {'OK'}

# Apply the function to determine which columns to drop
columns_to_drop = [col for col in df_pre.columns if is_column_to_drop(df_pre[col])]
df_pre.drop(columns=columns_to_drop, inplace=True)


output_path = 'data/train_preprocess2.csv'
df_pre.to_csv(output_path, index=False)

# %%
len(df_pre['Workorder_Dam'].unique())
# Out:
# 663

# %% [markdown]
# # Under Sampling data preprocess

# %%
df_preprocessed = preprocess_train_dataframe(df_concat)

# %%
df_preprocessed.shape
# Out:
# (4700, 102)

# %% [markdown]
# ### 데이터 분할

# %%
df_train, df_val = train_test_split(
    df_concat,
    test_size=0.3,
    stratify=df_concat["target"],
    random_state=RANDOM_STATE,
)


def print_stats(df: pd.DataFrame):
    num_normal = len(df[df["target"] == "Normal"])
    num_abnormal = len(df[df["target"] == "AbNormal"])

    print(f"  Total: Normal: {num_normal}, AbNormal: {num_abnormal}" + f" ratio: {num_abnormal/num_normal}")


# Print statistics
print(f"  \tAbnormal\tNormal")
print_stats(df_train)
print_stats(df_val)

# %% [markdown]
# ## 3. 모델 학습

# %% [markdown]
# ### 모델 정의

# %%
model = RandomForestClassifier(random_state=RANDOM_STATE)

# %% [markdown]
# ### 모델 학습

# %%
features = []

for col in df_train.columns:
    try:
        df_train[col] = df_train[col].astype(int)
        features.append(col)
    except:
        continue

train_x = df_train[features]
train_y = df_train["target"]

model.fit(train_x, train_y)

# %% [markdown]
# ## 4. 제출하기

# %% [markdown]
# ### 테스트 데이터 예측

# %% [markdown]
# 테스트 데이터 불러오기

# %%
test_data = pd.read_csv(os.path.join(ROOT_DIR, "test.csv"))

# %%
df_test_x = test_data[features]

for col in df_test_x.columns:
    try:
        df_test_x.loc[:, col] = df_test_x[col].astype(int)
    except:
        continue

# %%
test_pred = model.predict(df_test_x)
test_pred

# %% [markdown]
# ### 제출 파일 작성

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["target"] = test_pred

# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)

# %% [markdown]
# **우측 상단의 제출 버튼을 클릭해 결과를 확인하세요**
